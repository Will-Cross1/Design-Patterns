# %% [markdown]
# # Support Ticket System
#
# This will use the <font color="blue">Observer design pattern</font> for the purposes of showing an example of another design pattern and why it is inferior to the Chain-of-responsibility design pattern for this scenario.
#
# This pattern creates a subject That will notify any subscribers on changes, in this example, the craete_ticket() method. However, pure observers will mean that every observer subscribed to it will run, as they cannot have a responsibility chain by default, because all observers recieve an update, regardless if they are next in any sequence or not, they will all respond which means the observer design pattern alone can not meet the requirements for the scenario.
#
# Instead, a small hybrid approach with the chain-of-responsibliity design pattern was created to give the observers some logic capabilities, even then this method does not meet the requirement in exactly the way described in the scenario.

# %% [markdown]
# ## Create the observer class
#
# This is what the subscribed observers will be watching. Every time a ticket is made, notify is called which notifies all subscribed observers.

# %%
# Observer

# What is being observed (subject)
# Whenever a ticket is created, all subscribed observers are notified
class TicketSystem:
    def __init__(self):
        self.observers = []

    # Allows support levels to subscribe to ticket events
    def subscribe(self, observer):
        self.observers.append(observer)

    # Notifies every subscribed observer about the event
    def notify(self, ticket):
        for observer in self.observers:
            observer.update(ticket)

    # Creates a ticket and informs all observers.
    def create_ticket(self, ticket):
        print(f"{ticket.category.capitalize()} ticket created")
        self.notify(ticket)

# %% [markdown]
# ## Mocked ticket handling
#
# This is where each staff layer would manage the tickets, which is mocked using a simple print for this example.

# %%
# Mocked staff handling functions (identical to the Chain of Responsibility implementation)
# In a real application this is where each level of staff would be able to close or talk to the user for example
def level_1_staff_mock(ticket):
    print("Handled by Level 1 staff")
    print(f"Ticket with description: {ticket.description}")
    print("")

def level_2_staff_mock(ticket):
    print("Handled by Level 2 staff")
    print(f"Ticket with description: {ticket.description}")
    print("")

def level_3_staff_mock(ticket):
    print("Handled by Level 3 staff")
    print(f"Ticket with description: {ticket.description}")
    print("")

# %% [markdown]
# ## Create the observers
#
# These observers contain ticket filtering logic to better meet the scenario requirements. Unfortunately, this does stray from regular observer implementation because the observers are now responsible for deciding if they should handle the ticket.
#
# Demonstraiting the limitations of observer as the notification system works well, but routing the ticket and ticket escilation must be manually coded in. Whereas in the chain-of-responsibility design pattern, this is all the default.

# %%
# Different support level observers
class Level_1_Observer:
    def update(self, ticket):
        if ticket.category == "simple":
            level_1_staff_mock(ticket)
        else:
            print("Level 1 ignored ticket")


class Level_2_Observer:
    def update(self, ticket):
        if ticket.category == "complex":
            level_2_staff_mock(ticket)
        else:
            print("Level 2 ignored ticket")


class Level_3_Observer:
    def update(self, ticket):
        if ticket.category == "management":
            level_3_staff_mock(ticket)
        else:
            print("Level 3 ignored ticket")

# %% [markdown]
# ## Ticket class
#
# This is the class used to create tickets, and will be passed around each support level. In production more information will be included with this inclusing the user who raised it.

# %%
# Ticket information (identical to the Chain of Responsibility implementation)
class Ticket:
    def __init__(self, category, description):
        self.category = category
        self.description = description

# %% [markdown]
# ## Example output prints and usage
#
# Here the subject is being created
#
# I include four example tickets that are created here, but can be created elsewhere for a real application. These tickets are made in a seperate function for readability (create_ticket_structure())
#
# - A simple ticket: Level 1
# - A complex ticket: Level 2
# - A management ticket: Level 3
# - An unknown ticket (where did that come from??): Level ?
#
# The unknown ticket is to show that nothing will accept the ticket with this implementation meaning the ticket is lost and will remain unresolved. This is because observer has no central ownership of tickets after they have been notified.

# %%
def create_ticket_structure():
    simple_ticket = Ticket("simple", "A user can't find the power button on their PC.")
    complex_ticket = Ticket("complex", "A user has accidentally downloaded multiple viruses.")
    management_ticket = Ticket("management", "A shareholder wants to sell all of their shares!")
    unknown_ticket = Ticket("unknown", "t̴h̸e̵ ̷s̵t̴a̵r̴s̷ ̶a̴r̵e̴ ̶n̵o̷t̷ ̵w̵h̶a̶t̶ ̵t̵h̶e̵y̷ ̷s̸e̴e̷m̴")
    return simple_ticket, complex_ticket, management_ticket, unknown_ticket

if __name__ == "__main__":
    # Create ticket system subject
    ticket_system = TicketSystem()
    
    # create example ticket types
    simple_ticket, complex_ticket, management_ticket, unknown_ticket = create_ticket_structure()

    # Support levels subscribe to ticket creation events
    ticket_system.subscribe(Level_1_Observer())
    ticket_system.subscribe(Level_2_Observer())
    ticket_system.subscribe(Level_3_Observer())

    ticket_system.create_ticket(simple_ticket)
    print("\n\n")
    
    ticket_system.create_ticket(complex_ticket)
    print("\n\n")
    
    ticket_system.create_ticket(management_ticket)
    print("\n\n")
    
    ticket_system.create_ticket(unknown_ticket)
    print("\n\n")
# Out:
# Simple ticket created
# Handled by Level 1 staff
# Ticket with description: A user can't find the power button on their PC.
#
# Level 2 ignored ticket
# Level 3 ignored ticket
#
#
#
# Complex ticket created
# Level 1 ignored ticket
# Handled by Level 2 staff
# Ticket with description: A user has accidentally downloaded multiple viruses.
#
# Level 3 ignored ticket
#
#
#
# Management ticket created
# Level 1 ignored ticket
# Level 2 ignored ticket
# Handled by Level 3 staff
# Ticket with description: A shareholder wants to sell all of their shares!
#
#
#
#
# Unknown ticket created
# Level 1 ignored ticket
# Level 2 ignored ticket
# Level 3 ignored ticket
